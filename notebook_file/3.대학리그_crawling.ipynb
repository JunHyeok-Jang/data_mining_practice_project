# %%
from bs4 import BeautifulSoup
import requests
import random
import pandas as pd
import time
import numpy as np

# %% [markdown]
# # 대학리그 항목

# %%
df1 = pd.DataFrame([])  # 2021 ~ 2011년 기록 담을 데이터프레임

# %%
str_list = ['http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=014&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=013&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=012&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=011&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=010&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=009&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=008&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=007&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=006&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=005&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=004&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=003&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=4&sh_season_gu=002&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           ]

# %%
code_list = [50005,40002,40001,50004,40005,50002,50006,40007,40003,40015,40006,50003] # 대학교 코드

# %%
def select_year(a):
    if a == '14':
        return '2021'
    elif a == '13':
        return '2021'
    elif a == '12':
        return '2020'
    elif a == '11':
        return '2020'
    elif a == '10':
        return '2019'
    elif a == '09':
        return '2018'
    elif a == '08':
        return '2017'
    elif a == '07':
        return '2016'
    elif a == '06':
        return '2015'
    elif a == '05':
        return '2014'
    elif a == '04':
        return '2013'
    elif a == '03':
        return '2012'
    else:
        return '2011'

# %%
def select_univ(a):
    if a == 50005:
        return '건국대학교'
    elif a == 40002:
        return '경희대학교'
    elif a == 40001:
        return '고려대학교'
    elif a == 50004:
        return '단국대학교'
    elif a == 40005:
        return '동국대학교'
    elif a == 50002:
        return '명지대학교'
    elif a == 50006:
        return '상명대학교'
    elif a == 40007:
        return '성균관대학교'
    elif a == 40003:
        return '연세대학교'
    elif a == 40015:
        return '조선대학교'
    elif a == 40006:
        return '중앙대학교'
    else:
        return '한양대학교'

# %%
for url_base in str_list:
    for page_num in code_list:
        try:
            url = url_base.format(page_num)
            r = requests.get(url)
            page = BeautifulSoup(r.content, 'html.parser', from_encoding='utf-8')
            info = page.select('tr.TAC.H40')
            for i in range(len(info)//2):
                add_list = []
                add_list.append([info[i].a.text])
                add_list.append(info[i+(len(info)//2)].text.split())
                
                # 기록 년도 추가
                year = select_year(url_base[-77:-75])
                add_list.append([year])
                
                # 대학교 추가
                univ = select_univ(page_num)
                add_list.append([univ])

                add_list = sum(add_list, [])
                df1= df1.append(pd.Series(add_list), ignore_index = True)
        except:
            continue
        
    interval = round(random.uniform(0.2,1.2),2)
    time.sleep(interval)

# %%
columns = ['선수명',
           '경기수',
           '전체 출전시간',
           '득점 전체','득점 평균',
          '2점슛 성공', '2점슛 시도', '2점슛 성공률',
          '3점슛 성공', '3점슛 시도', '3점슛 성공률',
          '자유투 성공', '자유투 시도', '자유투 성공률',
          '공격 리바운드', '수비 리바운드', '평균 리바운드',
          '전체 어시스트', '평균 어시스트',
          '스틸',
          '블록',
          '덩크슛 성공', '덩크슛 시도',
          '파울(자유튜유)', '파울(자유투무)',
          'IDF',
          '테크니컬 파울',
          '굿디펜스',
          '속공',
          'FBF',
          '턴오버',
          '팀 리바운드',
          '팀 턴오버',
          '대회년도',
          '대학교']

# %%
df1.columns = columns

# %%
df1
# Out:
#             선수명 경기수   전체 출전시간 득점 전체 득점 평균 2점슛 성공 2점슛 시도 2점슛 성공률 3점슛 성공 3점슛 시도  \
# 0           주현우   3  01:51:22    78    26     30     58   51.7%      0      0
# 1           정민수   3  01:47:06    38    12     11     24   45.8%      4     17
# 2           백지웅   3  01:42:12    32    10      3      5   60.0%      8     35
# 3           조환희   3  01:45:31    26     8      6     25   24.0%      3     16
# 4           최승빈   2  01:06:08    16     8      7     16   43.8%      0      7
# 5           배성재   3  00:39:07     9     3      3      6   50.0%      0      1
# 6           박상우   3  00:20:39     6     2      2      2  100.0%      0      8
# 7           조성준   3  00:25:37     6     2      1      8   12.5%      0      1
# 8           김도연   3  00:05:34     2     0      1      1  100.0%      0      2
# 9           하헌일   3  00:00:00     0     0      0      0    0.0%      0      0
# 10          김기태   3  00:05:18     0     0      0      0    0.0%      0      1
# ...

# %% [markdown]
# # MBC배 전국대학농구대회 항목

# %%
df2 = pd.DataFrame([])  # 2021 ~ 2011년 기록 담을 데이터프레임

# %%
str_list1 = ['http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=021&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=020&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=019&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=018&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=017&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=016&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=015&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=014&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=013&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=012&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=011&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=010&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=009&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=008&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=007&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=006&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=005&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=004&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=003&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=002&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC',
           'http://www.kubf.or.kr/record/tplayer.php?sh_sort_field=SUM_SCORE&sort_order=&sh_div=5&sh_season_gu=001&sh_game_type=01&sh_team_code={}&sh_sort_field=SUM_SCORE&sh_sort_order=DESC']

# %%
for url_base in str_list1:
    for page_num in code_list:
        try:
            url = url_base.format(page_num)
            r = requests.get(url)
            page = BeautifulSoup(r.content, 'html.parser', from_encoding='utf-8')
            info = page.select('tr.TAC.H40')
            for i in range(len(info)//2):
                add_list = []
                add_list.append([info[i].a.text])
                add_list.append(info[i+(len(info)//2)].text.split())
                
                # 기록 년도 추가
                year = int(int(url_base[-77:-75])+2000-2)
                add_list.append([year])
                
                # 대학교 추가
                univ = select_univ(page_num)
                add_list.append([univ])

                add_list = sum(add_list, [])
                df2= df2.append(pd.Series(add_list), ignore_index = True)
        except:
            continue
        
    interval = round(random.uniform(0.2,1.2),2)
    time.sleep(interval)

# %%
df2.columns = columns

# %%
df2
# Out:
#             선수명 경기수   전체 출전시간 득점 전체 득점 평균 2점슛 성공 2점슛 시도 2점슛 성공률 3점슛 성공 3점슛 시도  \
# 0           이용우   3  01:53:03    67    22     10     25   40.0%     15     39
# 1           주현우   3  01:44:27    51    17     18     37   48.6%      0      0
# 2           최진광   3  01:45:43    49    16     11     24   45.8%      7     16
# 3           전태현   3  01:29:37    28     9      5     15   33.3%      6     20
# 4           최형욱   3  01:34:24    10     3      0      4    0.0%      3     12
# 5           정민수   3  00:25:18     9     3      3      7   42.9%      1      2
# 6           고성빈   3  00:20:22     5     1      1      2   50.0%      0      1
# 7           배성재   3  00:06:14     3     1      1      1  100.0%      0      0
# 8           남진식   3  00:36:02     3     1      0      2    0.0%      1      2
# 9           김기태   3  00:02:25     2     0      1      1  100.0%      0      0
# 10          이예환   3  00:02:25     2     0      1      1  100.0%      0      0
# ...

# %%
df1.to_csv('대학농구리그.csv', encoding='utf-8-sig')
df2.to_csv('MBC배 대학리그.csv', encoding='utf-8-sig')
